# %%
import requests
import pandas as pd

# %%
api_keys = '86442b53-97cd-4aac-a8d4-7025edca6902'
date='2021-01-01'
url = f'https://content.guardianapis.com/world/narendra-modi?from-date={date}&api-key={api_keys}&type=artical&page=1'

# %%
response =requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
x = response.json()

# %%
x
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 0,
#   'startIndex': 0,
#   'pageSize': 10,
#   'currentPage': 1,
#   'pages': 0,
#   'orderBy': 'newest',
#   'tag': {'id': 'world/narendra-modi',
#    'type': 'keyword',
#    'sectionId': 'world',
#    'sectionName': 'World news',
#    'webTitle': 'Narendra Modi',
#    'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#    'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#   'results': [],
#   'leadContent': [{'id': 'world/video/2024/jul/09/modi-tells-putin-that-the-heart-bleeds-when-innocent-children-are-killed-video',
#     'type': 'video',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webPublicationDate': '2024-07-09T15:31:40Z',
#     'webTitle': "Modi tells Putin that the 'heart bleeds' when innocent children are killed – video",
# ...

# %%
urlList=[]
for i in range(1,11):
    url = f'https://content.guardianapis.com/world/narendra-modi?from-date={date}&api-key={api_keys}&type=artical&page={i}'
    urlList.append(url)

# %%
print(urlList)
# Out:
# ['https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=86442b53-97cd-4aac-a8d4-7025edca6902&type=artical&page=1', 'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=86442b53-97cd-4aac-a8d4-7025edca6902&type=artical&page=2', 'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=86442b53-97cd-4aac-a8d4-7025edca6902&type=artical&page=3', 'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=86442b53-97cd-4aac-a8d4-7025edca6902&type=artical&page=4', 'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=86442b53-97cd-4aac-a8d4-7025edca6902&type=artical&page=5', 'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=86442b53-97cd-4aac-a8d4-7025edca6902&type=artical&page=6', 'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=86442b53-97cd-4aac-a8d4-7025edca6902&type=artical&page=7', 'ht
# ...

# %%
info = []

# %%
def json_fun(url):
    response= requests.get(url)
    x = response.json()
    info.append(x)

# %%
for url in urlList:
    json_fun(url)

# %%
info
# Out:
# [{'response': {'status': 'ok',
#    'userTier': 'developer',
#    'total': 0,
#    'startIndex': 0,
#    'pageSize': 10,
#    'currentPage': 1,
#    'pages': 0,
#    'orderBy': 'newest',
#    'tag': {'id': 'world/narendra-modi',
#     'type': 'keyword',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webTitle': 'Narendra Modi',
#     'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#     'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#    'results': [],
#    'leadContent': [{'id': 'world/video/2024/jul/09/modi-tells-putin-that-the-heart-bleeds-when-innocent-children-are-killed-video',
#      'type': 'video',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webPublicationDate': '2024-07-09T15:31:40Z',
#      'webTitle': "Modi tells Putin that the 'heart bleeds' when innocent children are killed – video",
# ...

# %%
len(info)
# Out:
# 10

# %%
info[0]['response']
# Out:
# {'status': 'ok',
#  'userTier': 'developer',
#  'total': 0,
#  'startIndex': 0,
#  'pageSize': 10,
#  'currentPage': 1,
#  'pages': 0,
#  'orderBy': 'newest',
#  'tag': {'id': 'world/narendra-modi',
#   'type': 'keyword',
#   'sectionId': 'world',
#   'sectionName': 'World news',
#   'webTitle': 'Narendra Modi',
#   'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#   'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#  'results': [],
#  'leadContent': [{'id': 'world/video/2024/jul/09/modi-tells-putin-that-the-heart-bleeds-when-innocent-children-are-killed-video',
#    'type': 'video',
#    'sectionId': 'world',
#    'sectionName': 'World news',
#    'webPublicationDate': '2024-07-09T15:31:40Z',
#    'webTitle': "Modi tells Putin that the 'heart bleeds' when innocent children are killed – video",
#    'webUrl': 'https://www.theguardian.com/world/video/2024/jul/09/modi-tells-putin-that-the-heart-bleeds-when-innocent-children-are-killed-video',
# ...

# %%
info[0]['response'][''][4]['webTitle']
# Out:
# 'Narendra Modi faces first coalition test as allied parties demand cabinet seats'

# %%
finallist = []
try:
    for k in range(1,10):
        for j in range(0,10):
            value = dict(webtitle=info[k]['response']['leadContent'][j]['webTitle'],
            sectionname = info[k]['response']['leadContent'][j]['sectionName'],
            publishddate=info[k]['response']['leadContent'][j]['webPublicationDate'])
            finallist.append(value)
except Exception as e:
    print('Error',e)

# %%
finallist
datanew = pd.DataFrame(finallist)

# %%
datanew
# Out:
#                                              webtitle sectionname  \
# 0   Modi tells Putin that the 'heart bleeds' when ...  World news
# 1   Modi and Putin cement ‘bonds of friendship’ de...  World news
# 2   Vladimir Putin takes Narendra Modi for a drive...  World news
# 3   Consensus or division? How Modi will manage In...  World news
# 4   Narendra Modi faces first coalition test as al...  World news
# ..                                                ...         ...
# 85  Modi loses parliamentary majority in Indian el...  World news
# 86  Narendra Modi loses aura of invincibility as p...  World news
# 87  Modi claims Indian election victory despite li...  World news
# 88  ‘Messianic spell’: how Narendra Modi created a...  World news
# 89  Narendra Modi inaugurates Hindu temple on site...  World news
#
#             publishddate
# 0   2024-07-09T15:31:40Z
# 1   2024-07-09T14:25:08Z
# 2   2024-07-09T09:42:05Z
# 3   2024-06-17T07:27:53Z
# 4   2024-06-06T17:10:53Z
# ...
